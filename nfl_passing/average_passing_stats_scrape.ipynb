# %%
import pandas as pd

dfs = pd.read_html('https://www.pro-football-reference.com/years/NFL/passing.htm')
league_passing = dfs[0]
league_passing.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',    'Rk'),
#             ('Unnamed: 1_level_0',  'Year'),
#             ('Unnamed: 2_level_0',   'Tms'),
#             (           'Passing',   'Cmp'),
#             (           'Passing',   'Att'),
#             (           'Passing',  'Cmp%'),
#             (           'Passing',   'Yds'),
#             (           'Passing',    'TD'),
#             (           'Passing',   'TD%'),
#             (           'Passing',   'Int'),
#             (           'Passing',  'Int%'),
#             (           'Passing',   'Y/A'),
#             (           'Passing',  'AY/A'),
#             (           'Passing',   'Y/C'),
#             (           'Passing',   'Y/G'),
#             (           'Passing',  'Rate'),
#             (           'Passing',    'Sk'),
#             (           'Passing', 'Yds.1'),
#             (           'Passing',  'NY/A'),
#             (           'Passing', 'ANY/A'),
#             (           'Passing',   'Sk%')],
# ...

# %%
league_passing.columns = league_passing.columns.to_flat_index()
league_passing.columns
# Out:
# Index([  ('Unnamed: 0_level_0', 'Rk'), ('Unnamed: 1_level_0', 'Year'),
#         ('Unnamed: 2_level_0', 'Tms'),             ('Passing', 'Cmp'),
#                    ('Passing', 'Att'),            ('Passing', 'Cmp%'),
#                    ('Passing', 'Yds'),              ('Passing', 'TD'),
#                    ('Passing', 'TD%'),             ('Passing', 'Int'),
#                   ('Passing', 'Int%'),             ('Passing', 'Y/A'),
#                   ('Passing', 'AY/A'),             ('Passing', 'Y/C'),
#                    ('Passing', 'Y/G'),            ('Passing', 'Rate'),
#                     ('Passing', 'Sk'),           ('Passing', 'Yds.1'),
#                   ('Passing', 'NY/A'),           ('Passing', 'ANY/A'),
#                    ('Passing', 'Sk%')],
#       dtype='object')

# %%
league_passing.columns = [col[1] for col in league_passing.columns]
league_passing.head()
# Out:
#   Rk  Year Tms   Cmp   Att  Cmp%    Yds   TD  TD%  Int  ...  Y/A AY/A   Y/C  \
# 0  1  2019  32  22.1  34.9  63.5  235.0  1.6  4.5  0.8  ...  7.2  7.1  11.4
# 1  2  2018  32  22.4  34.5  64.9  237.8  1.7  4.8  0.8  ...  7.4  7.3  11.4
# 2  3  2017  32  21.2  34.2  62.1  224.4  1.4  4.2  0.8  ...  7.0  6.8  11.3
# 3  4  2016  32  22.5  35.7  63.0  241.5  1.5  4.3  0.8  ...  7.2  7.0  11.4
# 4  5  2015  32  22.5  35.7  63.0  243.8  1.6  4.6  0.9  ...  7.3  7.1  11.5
#
#      Y/G  Rate   Sk Yds.1  NY/A ANY/A  Sk%
# 0  235.0  90.4  2.5  16.8  6.29   6.2  6.7
# 1  237.8  92.9  2.5  16.7  6.42   6.3  6.8
# 2  224.4  86.9  2.3  15.3  6.15   5.9  6.4
# 3  241.5  89.3  2.2  14.1  6.37   6.2  5.8
# 4  243.8  90.2  2.3  15.3  6.41   6.3  6.1
#
# [5 rows x 21 columns]

# %%
league_passing.columns
# Out:
# Index(['Rk', 'Year', 'Tms', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'TD%', 'Int',
#        'Int%', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate', 'Sk', 'Yds.1', 'NY/A',
#        'ANY/A', 'Sk%'],
#       dtype='object')

# %%
league_passing = league_passing.drop(columns=['Rk', 'Tms'])
league_passing.head()
# Out:
#    Year   Cmp   Att  Cmp%    Yds   TD  TD%  Int Int%  Y/A AY/A   Y/C    Y/G  \
# 0  2019  22.1  34.9  63.5  235.0  1.6  4.5  0.8  2.3  7.2  7.1  11.4  235.0
# 1  2018  22.4  34.5  64.9  237.8  1.7  4.8  0.8  2.4  7.4  7.3  11.4  237.8
# 2  2017  21.2  34.2  62.1  224.4  1.4  4.2  0.8  2.5  7.0  6.8  11.3  224.4
# 3  2016  22.5  35.7  63.0  241.5  1.5  4.3  0.8  2.3  7.2  7.0  11.4  241.5
# 4  2015  22.5  35.7  63.0  243.8  1.6  4.6  0.9  2.4  7.3  7.1  11.5  243.8
#
#    Rate   Sk Yds.1  NY/A ANY/A  Sk%
# 0  90.4  2.5  16.8  6.29   6.2  6.7
# 1  92.9  2.5  16.7  6.42   6.3  6.8
# 2  86.9  2.3  15.3  6.15   5.9  6.4
# 3  89.3  2.2  14.1  6.37   6.2  5.8
# 4  90.2  2.3  15.3  6.41   6.3  6.1

# %%
league_passing_num = league_passing.apply(pd.to_numeric, errors='coerce')
league_passing_num.head()
# Out:
#      Year   Cmp   Att  Cmp%    Yds   TD  TD%  Int  Int%  Y/A  AY/A   Y/C  \
# 0  2019.0  22.1  34.9  63.5  235.0  1.6  4.5  0.8   2.3  7.2   7.1  11.4
# 1  2018.0  22.4  34.5  64.9  237.8  1.7  4.8  0.8   2.4  7.4   7.3  11.4
# 2  2017.0  21.2  34.2  62.1  224.4  1.4  4.2  0.8   2.5  7.0   6.8  11.3
# 3  2016.0  22.5  35.7  63.0  241.5  1.5  4.3  0.8   2.3  7.2   7.0  11.4
# 4  2015.0  22.5  35.7  63.0  243.8  1.6  4.6  0.9   2.4  7.3   7.1  11.5
#
#      Y/G  Rate   Sk  Yds.1  NY/A  ANY/A  Sk%
# 0  235.0  90.4  2.5   16.8  6.29    6.2  6.7
# 1  237.8  92.9  2.5   16.7  6.42    6.3  6.8
# 2  224.4  86.9  2.3   15.3  6.15    5.9  6.4
# 3  241.5  89.3  2.2   14.1  6.37    6.2  5.8
# 4  243.8  90.2  2.3   15.3  6.41    6.3  6.1

# %%
passing_1982 = league_passing_num.query('Year >= 1982')
passing_1982.loc[:, 'Year'] = passing_1982.loc[:, 'Year'].astype('int16')
passing_1982
# Out:
# C:\Users\Adam\Miniconda3\envs\minimal_ds\lib\site-packages\pandas\core\indexing.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#     Year   Cmp   Att  Cmp%    Yds   TD  TD%  Int  Int%  Y/A  AY/A   Y/C  \
# 0   2019  22.1  34.9  63.5  235.0  1.6  4.5  0.8   2.3  7.2   7.1  11.4
# 1   2018  22.4  34.5  64.9  237.8  1.7  4.8  0.8   2.4  7.4   7.3  11.4
# 2   2017  21.2  34.2  62.1  224.4  1.4  4.2  0.8   2.5  7.0   6.8  11.3
# 3   2016  22.5  35.7  63.0  241.5  1.5  4.3  0.8   2.3  7.2   7.0  11.4
# 4   2015  22.5  35.7  63.0  243.8  1.6  4.6  0.9   2.4  7.3   7.1  11.5
# 5   2014  21.9  34.9  62.6  236.8  1.6  4.5  0.9   2.5  7.2   7.0  11.5
# ...

# %%
passing_1982.to_csv('average_passing_stats_1982_2019.csv', index=False)
